# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
#Get the Data from GitHub
ECom_Data='https://raw.githubusercontent.com/Isha03Shukla/E-Commerce/main/E-Commerce.csv'
ECom_Data=pd.read_csv(ECom_Data)

# %%
# Get the Data

#ECom_Data=pd.read_csv("E-Commerce.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %%
ECom_Data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %%
ECom_Data.columns #to check column names
# Out:
# Index(['Customer_uniq_id', 'Region', 'Order_Date', 'Expected_Delivery_Date',
#        'Delivered_Date', 'product_name', 'product_main_category',
#        'product_subcategory', 'product_category_filter',
#        'product_category_subfilter', 'product_unique ID', 'retail_price',
#        'discounted_price', 'product_rating', 'Brand', 'product_specifications',
#        'description'],
#       dtype='object')

# %% [markdown]
# #### Ans 1 a)

# %% [markdown]
# ### *The first 10 records of the data*

# %%
#The first 10 records of the data
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %% [markdown]
# ### *The last 10 records of the data.*

# %%
#The last 10 records of the data
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %%
ECom_Data.shape #shape is an attribute which returns tuple(Row,Columns)
# Out:
# (8906, 17)

# %% [markdown]
# Rows = 8906;
# Columns = 17

# %%
ECom_Data.info() #it returns the information of the dataset with rows and columns range.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# **Rows:** RangeIndex: 8906 entries, 0 to 8905
# **Columns:** Data columns (total 17 columns)

# %%
rows=len(ECom_Data) #it returns length of rows
print("Number of rows = ",rows)
# Out:
# Number of rows =  8906

# %%
col=ECom_Data.columns #it returns all the columns
print("Number of columns =",len(col)) #it will print the length of the column
# Out:
# Number of columns = 17

# %% [markdown]
# #### Ans  1 c)

# %%
ECom_Data.dtypes[ECom_Data.dtypes == 'object'].count()
# Out:
# 14

# %% [markdown]
# ### 14 object data types are there.
#
# ---
# We can also find object datatypes using ECom_Data.info(). As shown above it gives information regarding dtypes also.

# %% [markdown]
# ### Ans 1 d)

# %%
ECom_Data.dtypes[ECom_Data.dtypes == 'bool'].count()
# Out:
# 0

# %% [markdown]
# ### There is no Boolean data type present in this dataset.

# %%
#returns description of the data in the DataFrame
ECom_Data.describe()
# Out:
#         retail_price  discounted_price  product_rating
# count    8906.000000       8906.000000     8906.000000
# mean     1969.965304       1093.698518        3.066596
# std      3341.314408       2433.776099        1.413313
# min       115.000000        109.000000        1.000000
# 25%       730.000000        350.000000        2.000000
# 50%      1195.000000        599.000000        3.000000
# 75%      2199.000000       1199.000000        4.000000
# max    116292.000000     116292.000000        5.000000

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
ECom_Data.drop(['description', 'product_specifications'], axis=1)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %%
ECom_Data.columns
# Out:
# Index(['Customer_uniq_id', 'Region', 'Order_Date', 'Expected_Delivery_Date',
#        'Delivered_Date', 'product_name', 'product_main_category',
#        'product_subcategory', 'product_category_filter',
#        'product_category_subfilter', 'product_unique ID', 'retail_price',
#        'discounted_price', 'product_rating', 'Brand', 'product_specifications',
#        'description'],
#       dtype='object')

# %% [markdown]
# However, we can see that after dropping the product_specifications and description it is still present because it is not permanently deleted.

# %% [markdown]
# ### Ans 2 b)

# %%
ECom_Data.drop(['description', 'product_specifications'], axis=1,inplace=True)

# %%
ECom_Data.columns
# Out:
# Index(['Customer_uniq_id', 'Region', 'Order_Date', 'Expected_Delivery_Date',
#        'Delivered_Date', 'product_name', 'product_main_category',
#        'product_subcategory', 'product_category_filter',
#        'product_category_subfilter', 'product_unique ID', 'retail_price',
#        'discounted_price', 'product_rating', 'Brand'],
#       dtype='object')

# %% [markdown]
# inplace=True deletes the columns permanently. It means that this should work on original objects.

# %% [markdown]
# Two columns ['product_specifications','description'] deleted permanently from the dataset.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
print("Number of unique Brands =",ECom_Data['Brand'].nunique())
# Out:
# Number of unique Brands = 2484

# %%
ECom_Data.describe(include='object')
# Out:
#                         Customer_uniq_id Region  Order_Date  \
# count                               8906   8906        8906
# unique                              8906      4         127
# top     e71017e224688489edfe856f2308806d  East   07-01-2021
# freq                                   1   3421        1534
#
#        Expected_Delivery_Date Delivered_Date  \
# count                    8906           8906
# unique                    135            144
# top                10-01-2021     10-01-2021
# freq                     1532           1408
#
#                                       product_name product_main_category  \
# count                                         8906                  8906
# unique                                        5959                    26
# top     TheLostPuppy Back Cover for Apple iPad Air             Clothing
# freq                                           134                  2943
#
#        product_subcategory       product_category_filter  \
# ...

# %% [markdown]
# In the brand column we can see unique values = 2484

# %% [markdown]
# ### There are 2484 unique brands.

# %% [markdown]
# ### Ans 3 b)

# %%
ECom_Data.groupby(['Brand'])['product_rating'].mean()
# Out:
# Brand
# 1OAK           1.500000
# 3A AUTOCARE    3.268293
# 3D MAT         3.000000
# 3KFACTORY      2.000000
# 4D             3.600000
#                  ...
# ZORDEN         4.000000
# ZOSIGN         3.400000
# ZRESTHA        1.000000
# ZYXEL          3.333333
#  TARKAN        5.000000
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# #### Average rating for each brand is shown above.

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %%
ECom_Data['product_main_category'].nunique() #no. of unique product main category items
# Out:
# 26

# %% [markdown]
# There are **26** unique product main categories in this dataset.

# %%
ECom_Data['product_main_category'].value_counts().head(2) #Top two product_main_category(s) maximum order were placed.
# Out:
# Clothing                  2943
# Mobiles & Accessories     1084
# Name: product_main_category, dtype: int64

# %%
ECom_Data['product_main_category'].value_counts().tail(2) #two product_main_category(s) minimum order were placed.
# Out:
# Food & Nutrition           2
# Wearable Smart Devices     1
# Name: product_main_category, dtype: int64

# %%
ECom_Data.groupby(['product_main_category'])['product_subcategory'].value_counts() #rechecking all the product_main_category items counts
# Out:
# product_main_category    product_subcategory
# Automotive                Accessories & Spare parts     923
#                           Car & Bike Accessories         63
#                           Car Accessories                15
# Baby Care                 Infant Wear                   172
#                           Baby Bedding                   35
#                                                        ...
# Toys & School Supplies    Toy Guns & Weapons              1
# Watches                   Wrist Watches                  41
#                           Watch Accessories               6
#                           Clocks                          1
# Wearable Smart Devices    Wearable Accessories            1
# Name: product_subcategory, Length: 138, dtype: int64

# %% [markdown]
# ### Ans 4 a)

# %%
#Bar plot using seaborn library's countplot
plt.figure(figsize=(15,6))
plt.title('Bar: Product Category type')
plt.xlabel('product_main_category')
plt.ylabel('counts')
sns.countplot(data=ECom_Data,x='product_main_category');
plt.xticks(rotation=90)
plt.show()

# %%
#Barplot using order method so data is arranged in clean manner and maximum and minimum order can be seen clearly
plt.figure(figsize=(15,6))
plt.title('Barplot: Product Category type')
plt.xlabel('product_main_category')
plt.ylabel('counts')
sns.countplot(data=ECom_Data, x='product_main_category', order=ECom_Data['product_main_category'].value_counts(ascending=False).index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Ans 4 b)The two product_main_category(s) maximum order were placed are:
# 1) Clothing
# 2) Mobile & Accessories
#
# ---
# ###The two product_main_category(s) minimum orders were placed are:
#
# 1) Wearable Smart Devices
# 2) Food & Nutrition
#
# ## Maximum orders were placed for Clothing whereas minimum orders were placed for Wearable Smart Devices.

# %% [markdown]
# ### Ans 4 c)

# %%
ECom_Data['product_main_category'].value_counts().head(5) #Top five product_main_category(s) maximum order were placed.
# Out:
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: product_main_category, dtype: int64

# %% [markdown]
# ###The top 5 product_main_category(s) in descending order are:
#
# ####1) Clothing
# ####2) Mobiles & Accessories
# ####3) Automotive
# ####4) Home Decor & Festive Needs
# ####5) Computers

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
ECom_Data.head(2)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
#
#   product_main_category    product_subcategory product_category_filter  \
# 0             Clothing       Women's Clothing             Ethnic Wear
# 1    Pens & Stationery    Diaries & Notebooks               Notebooks
#
#   product_category_subfilter product_unique ID  retail_price  \
# 0                    Fabric   FABEJX2NHNKCYHKA           999
# 1                  Designer   DIAEJ6Z8BEDTGGYY           499
#
#    discounted_price  product_rating      Brand
# 0               699             4.0   INDCROWN
# ...

# %%
#function to calculate the revenue
def cal_rev(final_price):
  if final_price > 600:
    return (final_price)*(25/100)
  elif final_price>350 and final_price<=650:
    return (final_price)*(15/100)
  elif final_price>100 and final_price<=350:
    return final_price * (10/100)
  else:
    return final_price * (5/100)

ECom_Data['Revenue'] = ECom_Data['discounted_price'].apply(cal_rev) #It will make a column 'Revenue' which will generate profit made by a business after discounted price
ECom_Data.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %%
Total_Revenue=ECom_Data['Revenue'].sum() #total sum of revenue
print("Total Revenue generated by the E-Commerce company over all orders placed =",Total_Revenue)
# Out:
# Total Revenue generated by the E-Commerce company over all orders placed = 2217486.85

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
ECom_Data['BrandRevenue'] = ECom_Data['discounted_price'] - ECom_Data['Revenue']
ECom_Data.groupby('Brand')['BrandRevenue'].sum().nlargest(10)
#ECom_Data.groupby('Brand')['BrandRevenue'].sum().sort_values(ascending=False).head(10) #we can do this way too
# Out:
# Brand
# ALLURE AUTO     498464.25
# GAGA            237390.00
# SLIM            212062.60
# DAILYOBJECTS    181980.00
# DIVINITI        143115.00
# THELOSTPUPPY    127287.50
# REGULAR         126536.50
# ENTHOPIA        123146.25
# ASUS             99241.50
# SPRINGWEL        88978.50
# Name: BrandRevenue, dtype: float64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
#Boxplot for Retail Price
plt.figure(figsize=(15, 6))
plt.xlim(-5000,140000)
plt.title('Boxplot: Retail Price')
plt.xlabel('Retail Price')
sns.axes_style('whitegrid')
sns.boxplot(data=ECom_Data,x='retail_price',color='red')
plt.show()

# %%
#Boxplot for Discounted Price
plt.figure(figsize=(20, 6))
plt.xlim(-1600,120000)
plt.title('Boxplot: Discounted Price')
plt.xlabel('Discounted Price')
sns.axes_style('whitegrid')
sns.boxplot(data=ECom_Data,x='discounted_price',color='yellow')
plt.show()

# %%
#Ans 6a) boxplots of retail_price & discounted_price
plt.figure(figsize=(21, 10))
plt.xlim(-1500,120000)
sns.axes_style('whitegrid')
ECom_Data[['retail_price','discounted_price']].boxplot(vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ### Ans 7 b) Yes, there are outliers in the data of retail_price and discounted_price.

# %% [markdown]
# ### Ans 7 c)

# %%
#Scatterplot of retail_price (x-axis) and discounted_price (y-axis)
plt.title('Scatterplot: Retail Price and Discounted Price')
plt.xlabel('Retail Price')
plt.ylabel('Discounted Price')
sns.axes_style('whitegrid')
sns.scatterplot(data=ECom_Data, x='retail_price',y='discounted_price',color='purple')
plt.show()

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %%
#total number of orders placed per Brand
number_of_orders=ECom_Data['Brand'].value_counts()
print(number_of_orders)
# Out:
# ALLURE AUTO       469
# REGULAR           300
# SLIM              267
# THELOSTPUPPY      250
# BLACK             147
#                  ...
# WRITEFLO            1
# JAZAM               1
# RADIUS              1
# I-STATIC            1
# AMBIKA LAHENGA      1
# Name: Brand, Length: 2484, dtype: int64

# %%
#total retail_price per Brand
retail_price_per_Brand=ECom_Data.groupby('Brand')['retail_price'].sum()
retail_price_per_Brand
# Out:
# Brand
# 1OAK             1698
# 3A AUTOCARE    107059
# 3D MAT           7250
# 3KFACTORY         399
# 4D              17500
#                 ...
# ZORDEN           3999
# ZOSIGN           6995
# ZRESTHA          1999
# ZYXEL           64742
#  TARKAN          1999
# Name: retail_price, Length: 2484, dtype: int64

# %%
#total discounted_price per Brand
discounted_price_per_Brand=ECom_Data.groupby('Brand')['discounted_price'].sum()
discounted_price_per_Brand
# Out:
# Brand
# 1OAK            1274
# 3A AUTOCARE    74134
# 3D MAT          6999
# 3KFACTORY        174
# 4D              7948
#                ...
# ZORDEN          2799
# ZOSIGN          6995
# ZRESTHA          899
# ZYXEL          35392
#  TARKAN          349
# Name: discounted_price, Length: 2484, dtype: int64

# %%
#total BrandRevenue generated per Brand
BrandRevenue_per_Brand=ECom_Data.groupby('Brand')['BrandRevenue'].sum()
BrandRevenue_per_Brand
# Out:
# Brand
# 1OAK            1015.40
# 3A AUTOCARE    55647.90
# 3D MAT          5249.25
# 3KFACTORY        156.60
# 4D              5961.00
#                  ...
# ZORDEN          2099.25
# ZOSIGN          5246.25
# ZRESTHA          674.25
# ZYXEL          26544.00
#  TARKAN          314.10
# Name: BrandRevenue, Length: 2484, dtype: float64

# %%
#creating a new dataframe and storing Brand specific information
new_dataframe = pd.DataFrame(columns=['retail_price_per_Brand','number_of_orders','discounted_price_per_Brand','BrandRevenue_per_Brand'])

new_dataframe['retail_price_per_Brand']=retail_price_per_Brand
new_dataframe['number_of_orders']=number_of_orders
new_dataframe['discounted_price_per_Brand']=discounted_price_per_Brand
new_dataframe['BrandRevenue_per_Brand']=BrandRevenue_per_Brand
new_dataframe
# Out:
#              retail_price_per_Brand  number_of_orders  \
# Brand
# 1OAK                           1698                 2
# 3A AUTOCARE                  107059                41
# 3D MAT                         7250                 1
# 3KFACTORY                       399                 1
# 4D                            17500                 5
# ...                             ...               ...
# ZORDEN                         3999                 1
# ZOSIGN                         6995                 5
# ZRESTHA                        1999                 1
# ZYXEL                         64742                 9
#  TARKAN                        1999                 1
#
#              discounted_price_per_Brand  BrandRevenue_per_Brand
# Brand
# 1OAK                               1274                 1015.40
# 3A AUTOCARE                       74134                55647.90
# 3D MAT                             6999                 5249.25
# ...

# %%
sns.pairplot(data=new_dataframe,vars=['number_of_orders','retail_price_per_Brand','discounted_price_per_Brand','BrandRevenue_per_Brand'],diag_kind='kde')
#sns.pairplot(data=new_dataframe,vars=['number_of_orders','retail_price_per_Brand','discounted_price_per_Brand','BrandRevenue_per_Brand'],diag_kind='hist')
plt.show()

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
ECom_Data.columns
# Out:
# Index(['Customer_uniq_id', 'Region', 'Order_Date', 'Expected_Delivery_Date',
#        'Delivered_Date', 'product_name', 'product_main_category',
#        'product_subcategory', 'product_category_filter',
#        'product_category_subfilter', 'product_unique ID', 'retail_price',
#        'discounted_price', 'product_rating', 'Brand', 'Revenue',
#        'BrandRevenue'],
#       dtype='object')

# %%
# Convert 'Order_Date' to datetime type
ECom_Data['Order_Date']=pd.to_datetime(ECom_Data['Order_Date'])
ECom_Data['Order_Date'].dt.strftime(date_format='%d/%m/%y')
# Out:
# <ipython-input-276-630931e089f9>:2: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
# 0       24/10/21
# 1       24/10/21
# 2       24/10/21
# 3       24/10/21
# 4       09/03/21
#           ...
# 8901    12/01/20
# 8902    12/01/20
# 8903    12/01/20
# 8904    12/01/20
# 8905    12/01/20
# Name: Order_Date, Length: 8906, dtype: object

# %%
#Order year and month
ECom_Data['Order_Month']= ECom_Data['Order_Date'].dt.strftime("%Y-%m")
ECom_Data['Order_Month']
# Out:
# 0       2021-10
# 1       2021-10
# 2       2021-10
# 3       2021-10
# 4       2021-03
#          ...
# 8901    2020-01
# 8902    2020-01
# 8903    2020-01
# 8904    2020-01
# 8905    2020-01
# Name: Order_Month, Length: 8906, dtype: object

# %%
#max revenue of each region
max_revenue_by_region = ECom_Data.groupby('Region')['Revenue'].max().reset_index()
max_revenue_by_region
# Out:
#   Region  Revenue
# 0  East    9258.5
# 1  North  11905.0
# 2  South  29073.0
# 3   West  11201.0

# %%
#a) Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately
plt.figure(figsize=(20, 7))
plt.title('Monthly Revenue for Different Regions')
plt.xlabel('Month')
plt.ylabel('Revenue')
ECom_Data = ECom_Data.sort_values(by='Order_Month')
#sns.lineplot(data=ECom_Data,x='Month', y='Revenue', hue='Year',errorbar=('ci', False),palette="rainbow")
#sns.lineplot(x='Year', y='Revenue', hue='Month', data=ECom_Data,errorbar=('ci', False))
#sns.lineplot(x='Month', y='Revenue', hue='Region', data=monthly_Revenue, palette='rainbow')
#sns.lineplot(x='Order_Month',y='Revenue',hue='Region',Data=ECom_Data,errorbar=('ci', False))
sns.lineplot(x='Order_Month', y='Revenue',hue ='Region',data=ECom_Data, errorbar=('ci', False))
plt.show()

# %%
# Group the data by 'Region' and find the maximum monthly revenue and corresponding month for each region
max_revenue_by_region = ECom_Data.groupby('Region').apply(lambda x: x.loc[x['Revenue'].idxmax()]).reset_index(drop=True)
print(max_revenue_by_region[['Region','Revenue','Order_Month' ]])
# Out:
#   Region  Revenue Order_Month
# 0  East    9258.5     2021-03
# 1  North  11905.0     2021-04
# 2  South  29073.0     2021-11
# 3   West  11201.0     2021-12

# %%
# Group the data by 'Region' and find the minimum monthly revenue and corresponding month for each region
min_revenue_by_region = ECom_Data.groupby('Region').apply(lambda x: x.loc[x['Revenue'].idxmin()]).reset_index(drop=True)
print(min_revenue_by_region[['Region', 'Revenue','Order_Month']])
# Out:
#   Region  Revenue Order_Month
# 0  East      10.9     2021-07
# 1  North     10.9     2021-07
# 2  South     11.0     2020-12
# 3   West     10.9     2021-04

# %% [markdown]
# ### Ans 9 b)
# **East**
#
# Best Month - 2021 03(March)
#
# Worst Month - 2021 07(July)
#
# ---
#
# **North**
#
# Best Month - 2021 04(April)
#
# Worst Month - 2021 07(July)
#
#
# ---
#
# **South**
#
# Best Month - 2021 11(November)
#
# Worst Month - 2020 12(December)
#
# ---
#
# **West**
#
# Best Month - 2021 12(December)
#
# Worst Month - 2021 04(April)

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
